# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                     title  year     name   type                character     n
# 0         Suuri illusioni  1985   Homo $  actor                   Guests  22.0
# 1     Battle of the Sexes  2017  $hutter  actor          Bobby Riggs Fan  10.0
# 2    Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan   NaN
# 3              Steve Jobs  2015  $hutter  actor  1988 Opera House Patron   NaN
# 4  Straight Outta Compton  2015  $hutter  actor              Club Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(cast.title)
# Out:
# 3554507

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
cast.sort('year')
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                      title  year  \
# 2475884                                         Miss Jerry  1894
# 547504                                          Miss Jerry  1894
# 457752                                          Miss Jerry  1894
# 1692218                              Soldiers of the Cross  1900
# 1692067                              Soldiers of the Cross  1900
# 591883                                             Valsons  1905
# 468045                         The Story of the Kelly Gang  1906
# 3415469                        The Story of the Kelly Gang  1906
# 1370251                        The Story of the Kelly Gang  1906
# 711431                         The Story of the Kelly Gang  1906
# 3548077                                      Lika mot lika  1906
# ...

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(cast[cast.title == 'Hamlet'])
# Out:
# 313

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(cast[cast.title == 'North by Northwest'])
# Out:
# 111

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
cast[cast.title == 'Hamlet'].sort('year')
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           title  year                       name     type           character  \
# 1521931  Hamlet  1910          Jean Mounet-Sully    actor              Hamlet
# 1214884  Hamlet  1911            Oscar Langkilde    actor             Horatio
# 2386094  Hamlet  1911           Einar Zangenberg    actor             Laertes
# 2968458  Hamlet  1911               Ella La Cour  actress            Gertrude
# 1567972  Hamlet  1911                 Alwin Neu?    actor              Hamlet
# 940340   Hamlet  1911                Aage Hertel    actor            Claudius
# 3316367  Hamlet  1911              Emilie Sannom  actress             Ophelia
# 709408   Hamlet  1913  Johnston Forbes-Robertson    actor              Hamlet
# 1811708  Hamlet  1913               Percy Rhodes    actor           The Ghost
# ...

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
hi = (cast[cast.title == 'Hamlet']).sort('year')
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
print(hi)
# Out:
#           title  year                       name     type           character  \
# 1521931  Hamlet  1910          Jean Mounet-Sully    actor              Hamlet
# 1214884  Hamlet  1911            Oscar Langkilde    actor             Horatio
# 2386094  Hamlet  1911           Einar Zangenberg    actor             Laertes
# 2968458  Hamlet  1911               Ella La Cour  actress            Gertrude
# 1567972  Hamlet  1911                 Alwin Neu?    actor              Hamlet
# 940340   Hamlet  1911                Aage Hertel    actor            Claudius
# 3316367  Hamlet  1911              Emilie Sannom  actress             Ophelia
# 709408   Hamlet  1913  Johnston Forbes-Robertson    actor              Hamlet
# 1811708  Hamlet  1913               Percy Rhodes    actor           The Ghost
# 1815847  Hamlet  1913           G. (II) Richards    actor            Bernardo
# 1825694  Hamlet  1913             Walter Ringham    actor            Claudius
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(cast[cast.year == 1950])
# Out:
# 21928

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(cast[cast.year == 1960])
# Out:
# 18211

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len(cast[(cast.year >= 1950) & (cast.year <=1959)])
# Out:
# 209808

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
see = cast[cast.title == 'Batman'] 
see
# Out:
#           title  year                   name     type  \
# 93944    Batman  1943           Frank Austin    actor
# 94448    Batman  1943         William Austin    actor
# 111972   Batman  1989              Del Baker    actor
# 117367   Batman  1989        Michael Balfour    actor
# 147200   Batman  1989             David Baxt    actor
# 195866   Batman  1989          Paul Birchard    actor
# 207947   Batman  1989             Hugo Blick    actor
# 254492   Batman  1943           Lynton Brent    actor
# 282792   Batman  1943              Roy Bucko    actor
# 373804   Batman  1989             Carl Chase    actor
# 381823   Batman  1943        George Chesebro    actor
# 442646   Batman  1989     George Lane Cooper    actor
# 461731   Batman  1989           Harold Coyne    actor
# 462883   Batman  1989            Edwin Craig    actor
# 470182   Batman  1943          Douglas Croft    actor
# 470183   Batman  1943          Douglas Croft    actor
# ...

# %%
a = see.year.nunique()
a
# Out:
# 2

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
Inception = cast[cast.title == 'Inception']

# %%
len(Inception.type) #number of roles
# Out:
# 77

# %%
Inception.type.nunique() #number of unique roles
# Out:
# 2

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
Inception.n.isnull().sum()
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
Inception.n.notnull().sum()
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
North = cast[cast.title == 'North by Northwest']
North_n = North[North.n.notnull()]
North_n.sort('n')
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                       title  year                  name     type  \
# 827711   North by Northwest  1959            Cary Grant    actor
# 3308882  North by Northwest  1959       Eva Marie Saint  actress
# 1383389  North by Northwest  1959           James Mason    actor
# 2976957  North by Northwest  1959   Jessie Royce Landis  actress
# 338312   North by Northwest  1959        Leo G. Carroll    actor
# 2877697  North by Northwest  1959  Josephine Hutchinson  actress
# 1609857  North by Northwest  1959           Philip Ober    actor
# 1210346  North by Northwest  1959         Martin Landau    actor
# 2322114  North by Northwest  1959         Adam Williams    actor
# 1719980  North by Northwest  1959          Edward Platt    actor
# 632374   North by Northwest  1959     Robert Ellenstein    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
Sleuth = cast[(cast.title == 'Sleuth') & (cast.year == 1972)]
a = Sleuth.sort('n')
a.name
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
# 1619474      Laurence Olivier
# 309696          Michael Caine
# 354738         Alec Cawthorne
# 1391194    John (II) Matthews
# 2579049    Eve (III) Channing
# 1375438          Teddy Martin
# Name: name, dtype: object

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
Sleuth = cast[(cast.title == 'Sleuth') & (cast.year == 2007)]
a = Sleuth.sort('n')
a.name
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
# 309697           Michael Caine
# 1227880               Jude Law
# 1714832          Harold Pinter
# 246165         Kenneth Branagh
# 354739     Alec (II) Cawthorne
# 2579048      Eve (II) Channing
# 3173313      Carmel O'Sullivan
# Name: name, dtype: object

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
Ham = cast[(cast.title == 'Hamlet') & (cast.year == 1921)]
Ham.type.count()
# Out:
# 9

# %%
len(Ham.type) #should be same as count()
# Out:
# 9

# %%
Ham.type.nunique()
# Out:
# 2

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
Ham = cast[(cast.title == 'Hamlet') & (cast.year == 1996)]
Ham.type.count()
# Out:
# 54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
Ham = cast[cast.title == 'Hamlet']
Ham.type.count()
# Out:
# 313

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
Op = cast[cast.title == 'Ophelia']
Op
# Out:
#            title  year          name     type character   n
# 3272433  Ophelia  2018  Daisy Ridley  actress   Ophelia NaN
# 3499850  Ophelia  2018   Naomi Watts  actress  Gertrude NaN

# %%
Op.name.count()
# Out:
# 2

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
Dude = cast[cast.character == 'The Dude']

# %%
Dude.name.nunique()
# Out:
# 17

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
Strange = cast[cast.character == 'The Stranger']

# %%
Strange.name.nunique()
# Out:
# 197

# %%
Strange.name.count()
# Out:
# 208

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
Sid = cast[cast.name == 'Sidney Poitier']
Sid
# Out:
#                                 title  year            name   type  \
# 1724587               A Patch of Blue  1965  Sidney Poitier  actor
# 1724588         A Piece of the Action  1977  Sidney Poitier  actor
# 1724589           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1724590               A Warm December  1973  Sidney Poitier  actor
# 1724591             All the Young Men  1960  Sidney Poitier  actor
# 1724592                Band of Angels  1957  Sidney Poitier  actor
# 1724593             Blackboard Jungle  1955  Sidney Poitier  actor
# 1724594                  Brother John  1971  Sidney Poitier  actor
# 1724595         Buck and the Preacher  1972  Sidney Poitier  actor
# 1724596      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1724597                Duel at Diablo  1966  Sidney Poitier  actor
# 1724598              Edge of the City  1957  Sidney Poitier  actor
# 1724599               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %%
Sid.title.count()
# Out:
# 43

# %%
Sid.type.nunique()
# Out:
# 1

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
Judy = cast[cast.name == 'Judi Dench']

# %%
Judy.title.count()
# Out:
# 54

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
c = cast[(cast.name == 'Cary Grant') & (cast.n == 2) & (cast.year >= 1940) & (cast.year <= 1949)]
c.sort('year')
# Out:
# /Users/sheena/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                    title  year        name   type    character    n
# 827708  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 827718    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
h = cast[(cast.year >= 1950) & (cast.year >= 1959) & (cast.type == 'actor')]
h.count()
# Out:
# title        1878122
# year         1878122
# name         1878122
# type         1878122
# character    1878122
# n            1192123
# dtype: int64

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
h = cast[(cast.year >= 1950) & (cast.year >= 1959) & (cast.type == 'actress')]
h.count()
# Out:
# title        962616
# year         962616
# name         962616
# type         962616
# character    962616
# n            611664
# dtype: int64

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
z = cast[(cast.year <= 1980) & (cast.n == 2)]
z.count()
# Out:
# title        59830
# year         59830
# name         59830
# type         59830
# character    59830
# n            59830
# dtype: int64

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
z1 = cast[(cast.year <= 1980) & (cast.n != 2)]
z1.count()
# Out:
# title        1090685
# year         1090685
# name         1090685
# type         1090685
# character    1090685
# n             656212
# dtype: int64

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
z2 = cast[cast.year <= 1980]
z2['n'].notnull().sum()
# Out:
# 716042
